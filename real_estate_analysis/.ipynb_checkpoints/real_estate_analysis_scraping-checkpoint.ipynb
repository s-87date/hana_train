# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# SUUMO 中古マンション　飯田橋神楽坂市ヶ谷四ツ谷
url = 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160'

# %%
result = requests.get(url, timeout=10)
c = result.content
soup = BeautifulSoup(c, "html.parser")

# %%
# ページ数を取得
s = soup.find("div", {"class": "pagination pagination_set-nav"})
num_pages = int(s.find_all("a")[-2].string)

# 全てのページのURLを作成
urls = []
urls.append(url)
for i in range(num_pages-1):
    pg = str(i+2)
    url_page = url + '&pn=' + pg
    urls.append(url_page)

# %%
data = []
errors = []

# %%
print(urls)
# Out:
# ['https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=2', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=3', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=4', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=5', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=6', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=7', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=8', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=9', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=10', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=11', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=12', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=13', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=14', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=15', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=16', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=17', 'https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=18']

# %%
print(urls[0])
# Out:
# https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160

# %%
print(urls[1])
# Out:
# https://suumo.jp/jj/bukken/ichiran/JJ010FJ001/?ar=030&bs=011&ra=030013&rn=0025&rnek=002507710&rn=0070&rnek=007050030&rn=0305&rnek=030501820&rnek=030502980&rnek=030541160&pn=2

# %%
url = urls[0]

# %%
result = requests.get(url)
c = result.content
soup = BeautifulSoup(c, "html.parser")
summary = soup.find("div",{'id':'js-bukkenList'})
units = summary.find_all("div",{'class':'property_unit'})

# %%
unit=units[0]

# %%
# 物件詳細情報へのリンク
h2 = unit.find('h2', {'class':'property_unit-title'})
a = h2.find('a')
href = a.get('href')
link = 'https://suumo.jp' + href + 'bukkengaiyo/'

result_child = requests.get(link, timeout=10)
c_child = result_child.content
soup_child = BeautifulSoup(c_child, "html.parser")
summary_child = soup_child.find_all('tbody', {'class':'vat tal'})

# %%
print(summary_child)
# Out:
# [<tbody class="vat tal">
# <tr>
# <th class="cf w130 thSideLGray bdCell inkBgBrown vat tal">
# <div class="fl">物件名</div>
# <div class="fr w10 h10 mt1"></div>
# </th>
# <td class="w752 bdCell b" colspan="3">
# 							パールシティ小石川
# 							</td>
# </tr>
# <tr>
# <th class="cf w130 thSideLGray bdCell inkBgBrown vat tal">
# <div class="fl">価格</div>
# <div class="fr w10 h10 mt1"><a class="ic btOl icBeginner2 pr" href="javascript:void(0);" id="jsiHintMsKakaku">ヒント</a>
# <input id="jsiHintMsKakakuUrl" type="hidden" value="/front/edit/yogo/011_kakaku.html"/></div>
# </th>
# <td class="w290 bdCell">
# <p>
# 								1750万円
# 								</p>
# <p>[ <span class="fgOrange">□</span><a href="javascript:void(0);" id="jsiLoanWindow">支払シミュレーション</a> ]</p><input id="jsiLoanAmount" type="hidden" value="17500000">
# </input></td>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">
# <div class="fl">間取り</div>
# <div class="fr w10 h10 mt1"><a class="ic btOl icBeginner2 pr" href="javascript:void(0);" id="jsiHintMsMadori">ヒント</a>
# <input id="jsiHintMsMadoriUrl" type="hidden" value="/front/edit/yogo/011_madori.html"/></div>
# </th>
# <td class="w290 bdCell">
# <p>1DK
# </p>
# </td>
# </tr>
# <tr>
# <th class="cf w130 thSideLGray bdCell inkBgBrown vat tal">
# <div class="fl">販売戸数</div>
# <div class="fr w10 h10 mt1"><a class="ic btOl icBeginner2 pr" href="javascript:void(0);" id="jsiHintMsHanbaikosuu">ヒント</a>
# <input id="jsiHintMsHanbaikosuuUrl" type="hidden" value="/front/edit/yogo/011_hanbaikosuu.html"/></div>
# </th>
# <td class="w290 bdCell">
# 							1戸
# 							</td>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">
# <div class="fl">総戸数</div>
# <div class="fr w10 h10 mt1"><a class="ic btOl icBeginner2 pr" href="javascript:void(0);" id="jsiHintMsSoukosuu">ヒント</a>
# <input id="jsiHintMsSoukosuuUrl" type="hidden" value="/front/edit/yogo/011_soukosuu.html"/></div>
# </th>
# <td class="w290 bdCell">
# 							44戸
# 							</td>
# </tr>
# <tr>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">
# <div class="fl">専有面積</div>
# <div class="fr w10 h10 mt1"><a class="ic btOl icBeginner2 pr" href="javascript:void(0);" id="jsiHintMsSennyumenseki">ヒント</a>
# <input id="jsiHintMsSennyumensekiUrl" type="hidden" value="/front/edit/yogo/011_sennyumenseki.html"/></div>
# </th>
# <td class="w290 bdCell">
# 							25.05m<sup>2</sup>（壁芯）
# 							</td>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">
# <div class="fl">その他面積</div>
# <div class="fr w10 h10 mt1"><a class="ic btOl icBeginner2 pr" href="javascript:void(0);" id="jsiHintMsSonotamenseki">ヒント</a>
# <input id="jsiHintMsSonotamensekiUrl" type="hidden" value="/front/edit/yogo/011_sonotamenseki.html"/></div>
# </th>
# <td class="w290 bdCell">
# 							バルコニー面積：3.43m<sup>2</sup>
# </td>
# </tr>
# <tr>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">
# <div class="fl">所在階/構造・階建</div>
# <div class="fr w10 h10 mt1"><a class="ic btOl icBeginner2 pr" href="javascript:void(0);" id="jsiHintMsKouzoukaidate">ヒント</a>
# <input id="jsiHintMsKouzoukaidateUrl" type="hidden" value="/front/edit/yogo/011_kouzoukaidate.html"/></div>
# </th>
# <td class="w290 bdCell">
# 							7階/RC8階建
# 							</td>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal" style="padding:10px 6px;">
# <div class="fl">完成時期（築年月）</div>
# <div class="fr w10 h10 mt1"><a class="ic btOl icBeginner2 pr" href="javascript:void(0);" id="jsiHintMsKanseijiki">ヒント</a>
# <input id="jsiHintMsKanseijikiUrl" type="hidden" value="/front/edit/yogo/011_kanseijiki.html"/></div>
# </th>
# <td class="w290 bdCell">
# 							1984年8月
# 							</td>
# </tr>
# <tr>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">住所</th>
# <td class="w290 bdCell">
# <p>東京都文京区春日２</p>
# <p>[ <span class="fgOrange">■</span><a href="https://suumo.jp/ms/chuko/tokyo/sc_bunkyo/nc_91523585/kankyo/?fmlg=t001">周辺環境</a> ]</p>
# </td>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">交通</th>
# <td class="w290 bdCell">
# <div>東京メトロ丸ノ内線「後楽園」歩10分</div>
# <ul class="cf">
# <form action="https://go.ekitan.com/srv/i-jump/ikikata-jjnavi.jsp" method="post" name="norikaePop1Form" target="compinfo">
# <span id="norikaePop1Form">
# <input name="lndtr" type="hidden" value="%93%8C%8B%9E%83%81%83%67%83%8D%8A%DB%83%6D%93%E0%90%FC%81%75%8C%E3%8A%79%89%80%81%76%95%E010%95%AA"/>
# <input name="lndtm" type="hidden" value="10"/>
# <input name="lndmk" type="hidden" value="%83%70%81%5B%83%8B%83%56%83%65%83%42%8F%AC%90%CE%90%EC"/>
# <input name="lndst" type="hidden" value="14430"/>
# </span>
# <li class="fl">[ <a class="ic icNewWindows pl15" href="javascript:void(0);" id="jsiNorikaePop1" style="background-position:0 -45px; display:inline-block;">乗り換え案内</a> ]</li>
# </form>
# </ul>
# <div>都営大江戸線「飯田橋」歩10分</div>
# <ul class="cf">
# <form action="https://go.ekitan.com/srv/i-jump/ikikata-jjnavi.jsp" method="post" name="norikaePop2Form" target="compinfo">
# <span id="norikaePop2Form">
# <input name="lndtr" type="hidden" value="%93%73%89%63%91%E5%8D%5D%8C%CB%90%FC%81%75%94%D1%93%63%8B%B4%81%76%95%E010%95%AA"/>
# <input name="lndtm" type="hidden" value="10"/>
# <input name="lndmk" type="hidden" value="%83%70%81%5B%83%8B%83%56%83%65%83%42%8F%AC%90%CE%90%EC"/>
# <input name="lndst" type="hidden" value="01820"/>
# </span>
# <li class="fl">[ <a class="ic icNewWindows pl15" href="javascript:void(0);" id="jsiNorikaePop2" style="background-position:0 -45px; display:inline-block;">乗り換え案内</a> ]</li>
# </form>
# </ul>
# <div>都営大江戸線「春日」歩12分</div>
# <ul class="cf">
# <form action="https://go.ekitan.com/srv/i-jump/ikikata-jjnavi.jsp" method="post" name="norikaePop3Form" target="compinfo">
# <span id="norikaePop3Form">
# <input name="lndtr" type="hidden" value="%93%73%89%63%91%E5%8D%5D%8C%CB%90%FC%81%75%8F%74%93%FA%81%76%95%E012%95%AA"/>
# <input name="lndtm" type="hidden" value="12"/>
# <input name="lndmk" type="hidden" value="%83%70%81%5B%83%8B%83%56%83%65%83%42%8F%AC%90%CE%90%EC"/>
# <input name="lndst" type="hidden" value="08030"/>
# </span>
# <li class="fl">[ <a class="ic icNewWindows pl15" href="javascript:void(0);" id="jsiNorikaePop3" style="background-position:0 -45px; display:inline-block;">乗り換え案内</a> ]</li>
# </form>
# </ul>
# </td>
# </tr>
# <tr>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">関連リンク</th>
# <td class="w290 bdCell">
# <div>【この会社の関連サイト】</div>
# <ul>
# <li class="ic icArrowR pl10"><a href="https://www.ohkuraya.co.jp/Sell/result/office_cd/0900/" id="jsiFrontLogClickLinkEx1" rel="nofollow" target="new">当社契約実績</a></li>
# <input id="jsiKanrenLogLinkType1" type="hidden" value="52"/>
# <input id="jsiKanrenLogLinkKey1" type="hidden" value="1"/>
# <li class="ic icArrowR pl10"><a href="https://www.ohkuraya.co.jp/" id="jsiFrontLogClickLinkEx2" rel="nofollow" target="new">マンションご購入・ご売却はオークラヤ住宅へ。</a></li>
# <input id="jsiKanrenLogLinkType2" type="hidden" value="52"/>
# <input id="jsiKanrenLogLinkKey2" type="hidden" value="2"/>
# <li class="ic icArrowR pl10"><a href="https://www.ohkuraya.co.jp/Corporate/office/office_cd/0900/" id="jsiFrontLogClickLinkEx3" rel="nofollow" target="new">担当者紹介</a></li>
# <input id="jsiKanrenLogLinkType3" type="hidden" value="52"/>
# <input id="jsiKanrenLogLinkKey3" type="hidden" value="3"/>
# <li class="ic icArrowR pl10"><a href="https://www.ohkuraya.co.jp/Search/index/mode/new/" id="jsiFrontLogClickLinkEx4" rel="nofollow" target="new">新着物件情報</a></li>
# <input id="jsiKanrenLogLinkType4" type="hidden" value="52"/>
# <input id="jsiKanrenLogLinkKey4" type="hidden" value="4"/>
# <li class="ic icArrowR pl10"><a href="https://www.ohkuraya.co.jp/Sell/feature/" id="jsiFrontLogClickLinkEx5" rel="nofollow" target="new">オークラヤ住宅はここが違う</a></li>
# <input id="jsiKanrenLogLinkType5" type="hidden" value="52"/>
# <input id="jsiKanrenLogLinkKey5" type="hidden" value="5"/>
# </ul>
# </td>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">物件情報送信</th>
# <td class="w290 bdCell">
# <div class="cf">
# <div>この物件の詳細情報をパソコンやスマートフォン、携帯電話にメールで送れます。</div>
# <p class="mt5 zm1"><span class="kaiin_disp resort_inaka_kaiin_disp">
# <a class="bt_o btOl btnSendArticleInfo nyroModal" href="#mobileContent" id="kma">物件情報をメールに送る</a>
# </span></p>
# </div>
# </td>
# </tr>
# <tr>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">不動産会社ガイド</th>
# <td class="w752 bdCell" colspan="3">
# <p class="fs14 b fgGreen">会社やブランドを徹底研究していますので、是非ご覧ください。</p>
# <ul class="mt10">
# <li class="fl w310 ic icArrowR pl10">
# <a class="jscFrontLogClickLink" href="https://suumo.jp/jj/guide/shosai/JJ081FD001/?ar=030&amp;hp=000968029" target="new">オークラヤ住宅</a>
# </li>
# <input id="jsiFudosanGaidoLogLinkType" type="hidden" value="51"/>
# </ul>
# </td>
# </tr>
# <tr>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">担当者より</th>
# <td class="bdGrayB">
# <div class="cf">
# <div class="fl w96 h72 bdGray">
# <img alt="担当者" oncontextmenu="return(false);" src="https://img01.suumo.com/jj/resizeImage?src=gazo%2Fkaisha%2F030%2FN040001%2Fimg%2F68%2F000968_062_03_018.jpg&amp;w=96&amp;h=72"/>
# </div>
# <div class="fr w187">
# <div class="cf">
# <p class="fl mr5 fgGold fs14">担当者</p>
# <p class="fl pctStuff mt1 mr5">宅建</p>
# </div>
# <dl class="mt5">
# <dt>山崎　直樹</dt>
# <dd>年齢：30代</dd>
# <dd>業界経験：9年</dd>
# </dl>
# </div>
# </div>
# <div class="w290 mt5 bw">今までに数多くのご売却・ご購入のお手伝いをさせて頂きました。お客様のお気持ちを第一優先に、ご事情やご希望に合わせた的確なご提案ができるよう日々心掛けております。是非一度ご相談いただければ幸いです</div>
# </td>
# <td class="bdCell" colspan="2">
# <div class="w440 mt10">
# <span class="mr5">【得意エリア】</span>
# <span>文京区小石川・後楽・春日・白山・西片</span>
# </div>
# </td>
# </tr>
# <tr>
# <th class="w130 thSideLGray bdCell inkBgBrown vat tal">お問い合せ先</th>
# <td class="bdGrayB">
# <p><a class="jscToiawaseSakiWindow" href="javascript:void(0);">オークラヤ住宅(株)飯田橋営業所</a></p>
# <input class="jscToiawaseSakiWindowUrl" type="hidden" value="https://suumo.jp/chukomansion/kaisha/__JJ_JJ051FD001_arz1030z2bsz1011z2kcz1000968062.html"/>
# <p class="fgDRed">
# <span class="fs18 b">TEL：0800-603-0364
#
# 								</span>
# <span style="white-space: nowrap;">【通話料無料】</span>
# </p>
# <div>携帯電話・ＰＨＳからもご利用いただけます<br/>発信者番号は通知されません</div>
# <br/>
# <p class="fgDRed">「SUUMO(スーモ)を見た」と問い合わせください</p>
# <br/>
# <p>つながらない方、不動産会社の方は<a class="heikiToiawaseWindow" href="javascript:void(0);">こちら</a></p>
# <input class="heikiToiawaseWindowUrl" type="hidden" value="https://suumo.jp/jj/bukken/shosai/JJ012FD016/?ar=030&amp;bs=011&amp;nc=91523585&amp;heikiGamenShu=0"/>
# <br/>
# </td>
# <td class="bdCell" colspan="2">
# <p>免許番号：国土交通大臣（10）第003115号</p>
# <p>取引態様：＜仲介＞</p>
# <div class="mt5">
# <p>営業時間：9:20～18:10 ／ 定休日：火曜・水耀日</p>
# </div>
# </td>
# </tr>
# </tbody>, <tbody class="vat tal">
# <!-- ここからお名前 -->
# <tr>
# <th class="thSideDYellow bdCell bdGrayL bdGrayT vam">
# <div class="cf">
# <div class="fl">
# <p class="b">お名前</p>
# <!-- <p class="fgDRed">（必須）</p> -->
# </div>
# <p class="fr"><span class="formtabel_icon-required">必須</span></p>
# </div>
# </th>
# <td class="w478 thSideLYellow bdCell bdGrayT vam jscError">
# <p class="jscErrorMsg"></p>
# <!--
# --><div class="cf">
# <div class="fl mT6 mR108">姓名</div>
# <div class="fl mr10">
# <input class="requiredMustin js_exmple grp2 tf w300" id="FORM_007" name="seimeikanji" style="ime-mode:active" title="例）田中太郎" type="text" value=""/></div><!--
# --></div>
# <div class="mt10 cf">
# <div class="fl mT6 mR40">フリガナ(任意)</div>
# <div class="fl mr10"><input class="js_exmple tf w300" id="FORM_008" name="seimeikana" style="ime-mode:active" title="例）タナカタロウ" type="text" value=""/></div><!--
# -->
# </div>
# </td>
# </tr>
# <!-- ここからメールアドレス -->
# <!-- <tr>
# 		<td colspan="3" class="p0 h10"></td>
# 	</tr>
# 	<tr  >
# 		<th colspan="2" class="w163 thSideDYellow bdCell bdGrayL bdGrayT vam tal">
# 			<div class="cf">
# 				<div class="fl">
# 					<p class="b">メールアドレス</p>
# 					<p class="fgDRed">（必須）※PCメール推奨</p>
# 				</div>
# 				<p class="fr">半角<br />英数</p>
# 			</div>
# 		</th>
# 		<td class="w478 thSideLYellow bdCell bdGrayL bdGrayT vam jscError">
# 			<p class="jscErrorMsg"></p>
# 			<input type="text" name="email" maxlength="200" value="" id="FORM_011" style="ime-mode:disabled;" class="mail_address required tf w350"><div class="fs14">例） xxxxxx@suumo.jp</div>
# 		</td>
# 		<td class="vam w210">
# 			<p class="fgDRed">【注意】</p>
# 			<p>資料請求受付完了後に、<br />確認のメールをお送りいたします。</p>
# 		</td>
# 	</tr> -->
# <tr>
# <th class="thSideDYellow bdCell bdGrayL bdGrayT vam tal">
# <div class="cf">
# <div class="fl">
# <p class="b">メールアドレス</p>
# <p class="fgDRed">※PCメール推奨</p>
# </div>
# <p class="fr"><span class="formtable_ttl_required">半角<br>英数</br></span><span class="formtabel_icon-required">必須</span></p>
# </div>
# </th>
# <td class="w478 thSideLYellow bdCell bdGrayL bdGrayT vam jscError">
# <p class="jscErrorMsg"></p>
# <input class="mail_address requiredMustin js_exmple grp3 tf w592 ft140" id="FORM_011" maxlength="200" name="email" style="ime-mode:disabled;" title="例）xxxxxx@suumo.jp" type="text" value=""/><span class="mailunit-caption mT10 fl">※資料請求完了後に、確認メールをお送りいたします。</span>
# <!-- <div>例） カモメマンション203号室</div> -->
# </td>
# </tr>
# <tr>
# <th class="thSideDYellow bdCell bdGrayL bdGrayT vat tal">
# <div class="cf">
# <div class="fl">
# <p class="b">電話番号</p>
# <!-- <p class="fgDRed">（必須）</p> -->
# </div>
# <!-- <p class="fr">携帯OK<br />&nbsp;&nbsp;&nbsp;&nbsp;半角</p> -->
# <p class="fr"><span class="formtable_ttl_required">半角</span><span class="formtabel_icon-required">必須</span></p>
# </div>
# </th>
# <td class="w478 thSideLYellow bdCell bdGrayL bdGrayT vam jscError">
# <p class="jscErrorMsg"></p>
# <input class="requiredMustin js_exmple grp4 tf w200" maxlength="11" name="telno" style="ime-mode:disabled;" title="例）09012345678 ハイフン無し" type="text" value=""/><!-- <div>例03/090&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;例)  4567&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;例)  8910</div> -->
# <span class="ml15 mr5">連絡希望時間（任意）</span><!--
# --><input class="tel_time tf w80 js_exmple" id="FORM_012" maxlength="100" name="kiboujikantai" style="width:100px;" title="例）13時～15時" type="text" value=""/></td>
# </tr>
# <tr>
# <th class="w179 thSideDYellow bdCell bdGrayL bdGrayT vat tal" rowspan="3">
# <div class="cf">
# <div class="fl">
# <p class="b">ご住所</p>
# </div>
# <p class="fr"><span class="formtabel_icon-required">必須</span></p>
# </div>
# </th>
# <td class="w478 thSideLYellow bdCell bdGrayT vam jscError">
# <p class="jscErrorMsg"></p>
# <div class="fl mT6 mR80">郵便番号</div>
# <div class="fl mr10 zipunit">
# <input class="requiredMustin js_exmple grp5 tf w205" id="FORM_014" maxlength="7" name="yb" onkeyup="chooseYb()" style="ime-mode:disabled;" title="例）1234567" type="text" value=""/><div class="js_address_list address_entry_supporter"><!--/address_entry_supporter--></div>
# <span class="mailunit-caption mT10">※ハイフンなしで入力</span>
# <input id="tmpYb" name="tmpYb" type="hidden" value=""/><!-- <div>例） 123&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;例)  4567</div> -->
# </div>
# </td>
# <!-- <td rowspan="4" class="vam w210">
# 			<p class="fgDRed">【注意】</p>
# 			<p>不動産会社からのすみやかな資料配送ご連絡のため、メールアドレス･住所・電話番号を正しくご記入ください。</p>
# 		</td> -->
# </tr>
# <tr>
# <td class="w478 thSideLYellow bdCell bdGrayT vam jscError">
# <p class="jscErrorMsg"></p>
# <div class="fl mT3 mr24">都道府県・市区郡</div>
# <select class="required_multi_select grp6 tf" id="TODOFUKEN" name="tf" onchange="zipSearchClient.createShikugunList('/jj',this.value, '');return false;"><option value="">都道府県を選択</option><option value="01">北海道</option>
# <option value="02">青森県</option>
# <option value="03">岩手県</option>
# <option value="04">宮城県</option>
# <option value="05">秋田県</option>
# <option value="06">山形県</option>
# <option value="07">福島県</option>
# <option value="08">茨城県</option>
# <option value="09">栃木県</option>
# <option value="10">群馬県</option>
# <option value="11">埼玉県</option>
# <option value="12">千葉県</option>
# <option value="13">東京都</option>
# <option value="14">神奈川県</option>
# <option value="15">新潟県</option>
# <option value="16">富山県</option>
# <option value="17">石川県</option>
# <option value="18">福井県</option>
# <option value="19">山梨県</option>
# <option value="20">長野県</option>
# <option value="21">岐阜県</option>
# <option value="22">静岡県</option>
# <option value="23">愛知県</option>
# <option value="24">三重県</option>
# <option value="25">滋賀県</option>
# <option value="26">京都府</option>
# <option value="27">大阪府</option>
# <option value="28">兵庫県</option>
# <option value="29">奈良県</option>
# <option value="30">和歌山県</option>
# <option value="31">鳥取県</option>
# <option value="32">島根県</option>
# <option value="33">岡山県</option>
# <option value="34">広島県</option>
# <option value="35">山口県</option>
# <option value="36">徳島県</option>
# <option value="37">香川県</option>
# <option value="38">愛媛県</option>
# <option value="39">高知県</option>
# <option value="40">福岡県</option>
# <option value="41">佐賀県</option>
# <option value="42">長崎県</option>
# <option value="43">熊本県</option>
# <option value="44">大分県</option>
# <option value="45">宮崎県</option>
# <option value="46">鹿児島県</option>
# <option value="47">沖縄県</option></select><!-- -->
# <select class="required_multi_select grp6 tf" id="SHIGUNKU_CD" name="sc" onchange="this.form.selsc.value=this.value;"><option value="">市区郡を選択</option></select></td>
# </tr>
# <tr>
# <td class="w478 thSideLYellow bdCell bdGrayT vam jscError">
# <p class="jscErrorMsg"></p>
# <div class="fl mT6 mr10">町名・番地・建物名</div>
# <div class="fl">
# <input class="requiredMustin js_exmple grp7 tf w456" id="FORM_018" name="jushoshosaitatemonomei" title="例）銀座7-3-5 かもめマンション203号室" type="text" value=""/><span class="mailunit-caption mT10">※住所末尾までご入力ください。</span>
# </div>
# <!-- <div>例） 銀座7-3-5</div> -->
# </td>
# </tr>
# <tr>
# <th class="thSideDYellow bdCell bdGrayL bdGrayT vam tal" rowspan="2">
# <div class="cf">
# <div class="fl">
# <p class="b">その他</p>
# </div>
# </div>
# </th>
# <td class="w478 thSideLYellow bdCell bdGrayT vam jscError" nowrap="">
# <div class="fl mT6 mr10">
# <span class="db fl"><input checked="checked" class="cbf" id="autoInsertFlg" name="autoInsertFlg" type="checkbox" value="1"/></span>
# <span class="db ofh zm1"><label for="autoInsertFlg">この情報を他の問い合わせにも自動で反映（30分で破棄）</label></span>
# <div class="mT3 lh1_4 fgDGray">※一部物件でのみ利用可能となります</div>
# </div>
# </td>
# </tr>
# <tr>
# <td class="w478 thSideLYellow bdCell bdGrayT vam jscError" nowrap="">
# <div class="fl mT6 mr10">
# <span class="db fl"><input checked="checked" class="cbf" id="usefulMlFlg" name="usefulMlFlg" type="checkbox" value="1"/></span>
# <span class="db ofh zm1"><label for="usefulMlFlg">SUUMOお役立ちメールを受け取る</label></span>
# <div class="mT3 lh1_4 fgDGray">あなたにぴったりの物件情報やすぐに使えるノウハウをお届けします</div>
# </div>
# </td>
# </tr>
# </tbody>, <tbody class="vat tal">
# <tr id="jsiInquiry">
# <!--39369 <th class="w168 bgLGray bdCell bdGrayT vat tal"> -->
# <th class="bgLGray bdCell bdGrayL bdGrayT vat tal" style="width:228px!important">
# <p class="b">お問い合わせ内容</p>
# </th>
# <td class="bdCell bdGrayT thSideLYellow w478">
# <!--<p id="jsiInqCaution" class="error" style="display:none;">【注】未選択です。 </p>  -->
# <p class="error" id="jsiInqCaution" style="display:none;"></p>
# <p class="jscErrorMsg"></p>
# <ul class="cf w480">
# <li class="dibz w235 vat">
# <span class="db fl"><input class="cbf" id="jsiInq2" name="toiawase2" type="checkbox" value="1"/></span>
# <span class="db ofh zm1"><label for="jsiInq2">物件を実際に見てみたい</label></span>
# </li>
# <!-- <li class="dibz w235 vat"> -->
# <li class="dibz w320 vat">
# <span class="db fl"><input class="cbf" id="jsiInq4" name="toiawase4" type="checkbox" value="1"/></span>
# <span class="db ofh zm1"><label for="jsiInq4">物件探しや資金計画などのアドバイスが欲しい</label></span>
# </li>
# </ul>
# <p class="b mt10 submailhzunit-title" style="margin-top:10px;">【その他ご希望、ご要望等があればご記入ください。】</p>
# <textarea class="tf mt5 fs12 h85 js_exmple" cols="90" id="jsiInqComment" name="toiawasesonotacomment" title="例）予算3,000万円程度、希望間取り3LDK、希望エリア中央区で探しています。物件見学の希望日時は、今週末●/●の午後です。資料をFAXで送付してください。番号は電話番号と同じです。"></textarea></td>
# </tr>
# <!-- <tr>
# 		<th colspan="2" class="w163 bgLGray bdCell bdGrayL bdGrayT inkBgBrown vat tal">
# 			<div class="cf">
# 				<div class="fl">
# 					<p class="b">連絡ご希望の時間帯</p>
# 					<p>（任意）</p>
# 				</div>
# 				<p class="fr">全角<br />半角</p>
# 			</div>
# 		</th>
# 		<td class="w478 bdCell bdGrayL bdGrayT bgWhite vam jscError">
# 			<p class="error"></p>
# 			<input type="text" name="kiboujikantai" maxlength="100" value="" id="FORM_012" class="mail_address tf w350"><div>例） 13時～15時</div>
# 		</td>
# 		<td rowspan="3" class="vam w210">
# 		<p class="fgDRed">【注意】</p>
# 		<p>不動産会社によっては、資料をFAXで送付する場合がございます。<br />
# 			お持ちの方は番号をご入力ください。</p>
# 		</td>
# 	</tr>
# 	<tr  >
# 		<th colspan="2" class="w163 bgLGray bdCell bdGrayL bdGrayT inkBgBrown vat tal">
# 			<div class="cf">
# 				<div class="fl">
# 					<p class="b">FAX</p>
# 					<p>（任意）</p>
# 				</div>
# 				<p class="fr">半角</p>
# 			</div>
# 		</th>
# 		<td class="w478 bdCell bdGrayL bdGrayT bgWhite vam jscError">
# 			<p class="jscErrorMsg"></p>
# 			<div class="fl mr10">
# 				<input type="text" name="faxno1" maxlength="6" value="" id="jsiFaxNum1" style="ime-mode:disabled;" class="tf w50"><span class="ml5 mr5">-</span>
# 			 <input type="text" name="faxno2" maxlength="4" value="" id="jsiFaxNum2" style="ime-mode:disabled;" class="tf w50"><span class="ml5 mr5">-</span>
# 			 <input type="text" name="faxno3" maxlength="4" value="" id="jsiFaxNum3" style="ime-mode:disabled;" class="tf w50"><div>例)&nbsp;&nbsp;03&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;例)  1234&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;例)  5678</div>
# 			</div>
# 			<div class="fl">
# 				<input type="checkbox" name="faxInTel" value="1" id="jsiTelToFax" class="cbf"><label for="jsiTelToFax">電話番号と同じ</label>
# 			</div>
# 		</td>
# 	</tr>
# 	<tr>
# 		<th colspan="2" class="w163 bgLGray bdCell bdGrayL bdGrayT inkBgBrown vat tal">
# 			<p class="b">詳しい情報を対面で聞く</p>
# 			<p>（任意）</p>
# 		</th>
# 		<td class="w478 bdCell bdGrayL bdGrayT bgWhite vam jscError">
# 		<input type="checkbox" name="renrakutakuhou" value="1" id="FORM_029" class="jscCheckboxMm cbf"><label for="FORM_029">詳しい情報を対面で聞きたい</label>
# 		</td>
# 	</tr>
# 	</tbody>
# </table>
# <div class="cf">
# 	<div class="fl">
# 		<table class="mt10 pCell10 bdclps w690">
# 			<tbody class="vat tal"> -->
# <input name="baikyaku" type="hidden" value=""/><!-- <tr>
# 				<td colspan="2" class="p0 h10"></td>
# 			</tr> -->
# <tr>
# <!--39369 <th class="w166 bgLGray  bdCell bdGrayL bdGrayT inkBgBrown vam tal"> -->
# <th class="bgLGray bdCell bdGrayL bdGrayT inkBgBrown vam tal" style="width:228px!important">
# <!-- <p class="b">メールマガジン</p>
# 					<p>（任意）※PCメールのみ</p> -->
# <p class="b">SUUMOからのお知らせ（無料）</p>
# <span class="mailunit-caption">※メール受信制限をされている方は「suumo.jp」からのメール受信を許可してください。</span>
# </th>
# <td class="w470 bdCell bdGrayL bdGrayT thSideLYellow vam jscError">
# <div class="cf">
# <!-- <p class="fl mr10">ウィークリーメール：</p> -->
# <ul class="fl">
# <li>
# <input class="jscCheckboxMm cbf" id="FORM_450" name="magcd" type="checkbox" value="B11"/><label for="FORM_450">SUUMOメールマガジン／購入版・関東</label>
# </li>
# </ul>
# </div>
# </td>
# </tr>
# </tbody>]

# %%
print(unit)
# Out:
# <div class="property_unit property_unit--osusume">
# <div class="property_unit-input data_table">
# <p class="ui-sprite--mark_check">チェック</p>
# <input class="js-ikkatsuCB" id="bukken_1" name="bsnc" type="checkbox" value="01191523585"/>
# <label class="cbx_list" for="bukken_1"> </label>
# <input class="js-clipkey" type="hidden" value="91523585_011">
# </input></div>
# <div class="property_unit-content">
# <div class="property_unit-header">
# <h2 class="property_unit-title">
# <a href="/ms/chuko/tokyo/sc_bunkyo/nc_91523585/?suit=STkr20180612200" target="_blank">◆最上階角部屋◆通風良好◆新耐震基準◆事務所利用可（細則有）◆平成24年5…</a></h2>
# <div class="property_unit-action">
# <ul class="property_unit-action-btn">
# <li><a class="ui-sprite--actionbtn_addmylist js-addMyList" href="javascript:void(0);">お気に入りに追加する</a></li>
# <li><a class="ui-btn ui-btn--cta2 ui-btn--small2" href="/jj/bukken/shiryou/JJ010FJ010/?ar=030&amp;bs=011&amp;nc=91523585&amp;senimotokbn=1&amp;suit=STkr20180612207" rel="nofollow" title="資料請求する">資料請求する</a></li>
# </ul>
# </div>
# </div>
# <div class="property_unit-body ofh">
# <div class="ui-media">
# <div class="ui-media-object property_unit-object">
# <a class="ui-thumb ui-thumb--1" href="/ms/chuko/tokyo/sc_bunkyo/nc_91523585/?suit=STkr20180612201" target="_blank"><img alt="" class="js-noContextMenu js-scrollLazy" height="144" rel="https://img01.suumo.com/jj/resizeImage?src=gazo%2Fbukken%2F030%2FN010000%2Fimg%2F585%2F91523585%2F91523585_0020.jpg&amp;w=192&amp;h=144" src="...%3D%3D" width="192"/></a><div class="property_unit-thumb_group">
# <ul class="property_unit-thumb">
# <li>
# <a class="ui-thumb ui-thumb--1 ui-thumb--fit" href="/ms/chuko/tokyo/sc_bunkyo/nc_91523585/?suit=STkr20180612201" target="_blank"><img alt="" class="js-noContextMenu js-scrollLazy" height="69" rel="https://img01.suumo.com/jj/resizeImage?src=gazo%2Fbukken%2F030%2FN010000%2Fimg%2F585%2F91523585%2F91523585_0021.jpg&amp;w=92&amp;h=69" src="...%3D%3D" width="92"/></a></li>
# <li>
# <a class="ui-thumb ui-thumb--1 ui-thumb--fit property_unit-thumb-movelink" href="/ms/chuko/tokyo/sc_bunkyo/nc_91523585/?suit=STkr20180612201" target="_blank"><img alt="" class="js-noContextMenu js-scrollLazy" height="69" rel="https://suumo.smbb.jp/dvic/image.php?akey=6116898Mb2e66-c3V1bW8yLnNtYmIuanA=&amp;siteid=suumo.smbb.jp" src="...%3D%3D" width="92"/>
# <img alt="" class="property_unit-thumb-moveobject js-noContextMenu js-scrollLazy" height="69" rel="/edit/assets/suumo/img/move_92_69.png" src="...%3D%3D" width="92"/></a></li>
# </ul>
# </div>
# </div>
# <div class="ui-media-body property_unit-info">
# <div class="dottable dottable--cassette">
# <div class="dottable-line">
# <dl>
# <dt class="dottable-vm">物件名</dt>
# <dd class="dottable-vm">パールシティ小石川</dd>
# </dl>
# </div>
# <div class="dottable-line">
# <dl>
# <dt class="dottable-vm">販売価格</dt>
# <dd class="dottable-vm">
# <span class="dottable-value">1750万円</span>
# </dd>
# </dl>
# </div>
# <div class="dottable-line">
# <dl>
# <dt>所在地</dt>
# <dd>東京都文京区春日２</dd>
# </dl>
# <dl>
# <dt>沿線・駅</dt>
# <dd>都営大江戸線「飯田橋」徒歩10分</dd>
# </dl>
# </div>
# <div class="dottable-line">
# <table class="dottable-fix">
# <tbody>
# <tr>
# <td>
# <dl>
# <dt>専有面積</dt>
# <dd>25.05m<sup>2</sup>（壁芯）</dd>
# </dl>
# </td>
# <td>
# <dl>
# <dt>間取り</dt>
# <dd>1DK</dd>
# </dl>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="dottable-line">
# <table class="dottable-fix">
# <tbody>
# <tr>
# <td>
# <dl>
# <dt>バルコニー</dt>
# <dd>3.43m<sup>2</sup></dd>
# </dl>
# </td>
# <td>
# <dl>
# <dt>築年月</dt>
# <dd>1984年8月</dd>
# </dl>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="dottable-line">
# <div class="pickupphotos">
# <div class="pickupphotos-title">掲載写真</div>
# <div class="pickupphotos-desc">
# <span class="ui-icon ui-icon--camera_s"></span>おすすめ写真がそろってます
# 												</div>
# </div>
# <ul class="property_unit-info-pct ui-list--hz">
# <li><span class="ui-pct ui-label--cta3">間取り図</span></li>
# <li><span class="ui-pct ui-label--cta3">外観</span></li>
# <li><span class="ui-pct ui-label--cta3">リビング・居室</span></li>
# <li><span class="ui-pct ui-label--cta3">浴室</span></li>
# <li><span class="ui-pct ui-label--cta3">キッチン</span></li>
# <li><span class="ui-pct ui-label--cta3">玄関</span></li>
# <li><span class="ui-pct ui-label--cta3">収納</span></li>
# <li><span class="ui-pct ui-label--cta3">共有施設</span></li>
# <li><span class="ui-pct ui-label--cta3">周辺環境</span></li>
# <li><span class="ui-pct ui-label--cta3">バルコニー</span></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="moreinfo">
# <div class="moreinfo-box">
# <div class="makermore">
# <div class="makermore-repute">
# <div class="shopmore">
# <div class="shopmore-title">
# 											オークラヤ住宅(株)飯田橋営業所</div>
# </div>
# </div>
# <div class="makermore-tel">
# <span class="kr-list-icon kr_list-icon--tel"></span><span class="makermore-tel-txt">0800-603-0364</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
info= subtitle= price= location= station= area= floor_plan= balcony= yrs= link= kanrihi= shuzenhi= stair= direction= reform= total_units= structure= right_form= usage_district= parking='NA'
try:
    # 新着、価格更新等の情報
    info = unit.find('span',{'class':'ui-label ui-label--cta1 ui-label--cta4'}).string
except:
    pass

try:
    # 物件名
    subtitle = unit.find('dd',{'class':'dottable-vm'}).string
except:
    pass
try:
    # 価格
    price = unit.find('span',{'class':'dottable-value'}).string
except:
    pass

try:
    # 住所
    location = unit.find_all('dd')[2].string
except:
    pass

try:
    # 最寄駅
    station = unit.find_all('dd')[3].string
except:
    pass

try:
    # 専有面積
    area = unit.find_all('dd')[4].contents[0].split('m')[0]
except:
    pass

try:
    # 間取り
    floor_plan = unit.find_all('dd')[5].string
except:
    pass

try:
    # バルコニー
    balcony = unit.find_all('dd')[6].contents[0].split('m')[0]
except:
    pass

try:
    # 築年月
    yrs = unit.find_all('dd')[7].string
except:
    pass

try:
    # link
    link = unit.find('h2',{'class':'property_unit-title'}).a.get('href')
except:
    pass

try:
    # 管理費
    kanrihi = summary_child[0].find_all('td')[5].string.strip('\r\n\t')
except:
    pass

try:
    # 修繕積立費
    shuzenhi = summary_child[0].find_all('td')[6].string.strip('\r\n\t')
except:
    pass

try:
    #　物件階
    stair = summary_child[0].find_all('td')[14].string.strip('\r\n\t')
except:
    pass

try:
    #　方角
    direction = summary_child[0].find_all('td')[15].string.strip('\r\n\t')
except:
    pass

try:
    # リフォーム
    reform = summary_child[0].find_all('td')[16].contents
except:
    pass

try:
    # 総戸数
    total_units = summary_child[1].find_all('td')[2].string.strip('\r\n\t')
except:
    pass

try:
    # 構造・階建て
    structure = summary_child[1].find_all('td')[3].string.strip('\r\n\t')
except:
    pass

try:
    # 権利形態
    right_form = summary_child[1].find_all('td')[5].string.strip('\r\n\t')
except:
    pass

try:
    # 用途地域
    usage_district = summary_child[1].find_all('td')[6].string.strip('\r\n\t')
except:
    pass

try:
    # 駐車場
    parking = summary_child[1].find_all('td')[7].string.strip('\r\n\t')
except:
    pass

# %%
data.append([info, subtitle, price, location, station, area, floor_plan, balcony, yrs, link, kanrihi, shuzenhi, stair, direction, reform, total_units, structure, right_form, usage_district, parking])

# %%
# data listを DataFrameに変換
df = pd.DataFrame(data, columns=['情報','物件名','価格','住所','最寄駅','専有面積','間取り','バルコニー','築年月','リンク','管理費', '修繕積立費','物件階', '方角','リフォーム','総戸数', '構造・階建て','権利形態','用途地域','駐車場'])

# %%
df
# Out:
#    情報        物件名      価格         住所               最寄駅   専有面積  間取り バルコニー  \
# 0  NA  パールシティ小石川  1750万円  東京都文京区春日２  都営大江戸線「飯田橋」徒歩10分  25.05  1DK  3.43
#
#        築年月                                                リンク 管理費 修繕積立費 物件階  \
# 0  1984年8月  /ms/chuko/tokyo/sc_bunkyo/nc_91523585/?suit=ST...  NA    NA  NA
#
#    方角                                              リフォーム 総戸数 構造・階建て 権利形態 用途地域  \
# 0  NA  [
# , <p><a class="jscToiawaseSakiWindow" href="...  NA     NA   NA   NA
#
#   駐車場
# 0  NA

# %%
for url in urls:
    k = 0
    try:
        result = requests.get(url)
        c = result.content
        soup = BeautifulSoup(c, "html.parser")
        summary = soup.find("div",{'id':'js-bukkenList'})
        units = summary.find_all("div",{'class':'property_unit'})
        
        for unit in units:
            l = 0
            # 物件詳細情報へのリンク
            h2 = unit.find('h2', {'class':'property_unit-title'})
            a = h2.find('a')
            href = a.get('href')
            link = 'https://suumo.jp' + href + 'bukkengaiyo/'

            result_child = requests.get(link, timeout=10)
            c_child = result_child.content
            soup_child = BeautifulSoup(c_child, "html.parser")
            summary_child = soup_child.find_all('tbody', {'class':'vat tal'})
            
            info= subtitle= price= location= station= area= floor_plan= balcony= yrs= link= kanrihi= shuzenhi= stair= direction= reform= total_units= structure= right_form= usage_district= parking='NA'
            try:
                # 新着、価格更新等の情報
                info = unit.find('span',{'class':'ui-label ui-label--cta1 ui-label--cta4'}).string
            except:
                pass

            try:
                # 物件名
                subtitle = unit.find('dd',{'class':'dottable-vm'}).string
            except:
                pass
            
            try:
                # 価格
                price = unit.find('span',{'class':'dottable-value'}).string
            except:
                pass

            try:
                # 住所
                location = unit.find_all('dd')[2].string
            except:
                pass

            try:
                # 最寄駅
                station = unit.find_all('dd')[3].string
            except:
                pass

            try:
                # 専有面積
                area = unit.find_all('dd')[4].contents[0].split('m')[0]
            except:
                pass

            try:
                # 間取り
                floor_plan = unit.find_all('dd')[5].string
            except:
                pass

            try:
                # バルコニー
                balcony = unit.find_all('dd')[6].contents[0].split('m')[0]
            except:
                pass

            try:
                # 築年月
                yrs = unit.find_all('dd')[7].string
            except:
                pass

            try:
                # link
                link = unit.find('h2',{'class':'property_unit-title'}).a.get('href')
            except:
                pass

            try:
                # 管理費
                kanrihi = summary_child[0].find_all('td')[5].string.strip('\r\n\t')
            except:
                pass

            try:
                # 修繕積立費
                shuzenhi = summary_child[0].find_all('td')[6].string.strip('\r\n\t')
            except:
                pass

            try:
                #　物件階
                stair = summary_child[0].find_all('td')[14].string.strip('\r\n\t')
            except:
                pass

            try:
                #　方角
                direction = summary_child[0].find_all('td')[15].string.strip('\r\n\t')
            except:
                pass

            try:
                # リフォーム
                reform = summary_child[0].find_all('td')[16].contents
            except:
                pass

            try:
                # 総戸数
                total_units = summary_child[1].find_all('td')[2].string.strip('\r\n\t')
            except:
                pass

            try:
                # 構造・階建て
                structure = summary_child[1].find_all('td')[3].string.strip('\r\n\t')
            except:
                pass

            try:
                # 権利形態
                right_form = summary_child[1].find_all('td')[5].string.strip('\r\n\t')
            except:
                pass

            try:
                # 用途地域
                usage_district = summary_child[1].find_all('td')[6].string.strip('\r\n\t')
            except:
                pass

            try:
                # 駐車場
                parking = summary_child[1].find_all('td')[7].string.strip('\r\n\t')
            except:
                pass
            
            data.append([info, subtitle, price, location, station, area, floor_plan, balcony, yrs, link, kanrihi, shuzenhi, stair, direction, reform, total_units, structure, right_form, usage_district, parking])
            # data listを DataFrameに変換
            df = pd.DataFrame(data, columns=['情報','物件名','価格','住所','最寄駅','専有面積','間取り','バルコニー','築年月','リンク','管理費', '修繕積立費','物件階', '方角','リフォーム','総戸数', '構造・階建て','権利形態','用途地域','駐車場'])
    except Exception as e:
        errors.append([e, url, k, l, subtitle])
        pass

# %%
df

# %%
# csvファイルとして保存
df.to_csv('/Users/hanadate/work/hana_train/real_estate_analysis/dat/suumo_used_mansion.csv', sep = ',',encoding='utf-8')

# ついでに errors fileも保存
df_errors = pd.DataFrame(errors)
df_errors.to_csv('/Users/hanadate/work/hana_train/real_estate_analysis/dat/errors_used_mansion.csv', sep = ',', encoding='utf-8')
